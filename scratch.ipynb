# %%
import pandas as pd
import numpy as np

# %%
tjdata = pd.read_csv('trader_joes_product_details_cleaned.csv')
tjdata.columns
# Out:
# Index(['name', 'price', 'package_size', 'serving_size', 'calories_per_serving',
#        'calculated_calories', 'Total Fat', 'Saturated Fat', 'Trans Fat',
#        'Cholesterol', 'Sodium', 'Total Carbohydrate', 'Dietary Fiber',
#        'Total Sugars', 'Added Sugars', 'Protein', 'Vitamin D', 'Calcium',
#        'Iron', 'Potassium', 'Polyunsaturated Fat', 'Monounsaturated Fat',
#        'Vitamin A', 'Vitamin C', 'Insoluble Fiber', 'Soluble Fiber', 'Thiamin',
#        'Riboflavin', 'Niacin', 'Vitamin B6', 'Folate', 'Folic Acid',
#        'Vitamin B12', 'Zinc', 'Pantothenic Acid', 'Phosphorus',
#        'Calories from Fat', 'Trans Fat 0g',
#        '† As prepared with unsalted butter and salt.', 'Added SugarsƗ',
#        'Ɨ One  serving adds 16g of sugar to your diet and represents  32% of the Daily Value for Added Sugars'],
#       dtype='object')

# %%
tjdata.drop(['calories_per_serving', 'Saturated Fat', 'Trans Fat', 'Added Sugars', 'Polyunsaturated Fat', 'Monounsaturated Fat',
       'Vitamin A', 'Vitamin C', 'Insoluble Fiber', 'Soluble Fiber', 'Thiamin',
       'Riboflavin', 'Niacin', 'Vitamin B6', 'Folate', 'Folic Acid',
       'Vitamin B12', 'Zinc', 'Pantothenic Acid', 'Phosphorus',
       'Calories from Fat', 'Trans Fat 0g',
       '† As prepared with unsalted butter and salt.', 'Added SugarsƗ',
       'Ɨ One  serving adds 16g of sugar to your diet and represents  32% of the Daily Value for Added Sugars'], axis=1, inplace=True
           )
tjdata.columns
# Out:
# Index(['name', 'price', 'package_size', 'serving_size', 'calculated_calories',
#        'Total Fat', 'Cholesterol', 'Sodium', 'Total Carbohydrate',
#        'Dietary Fiber', 'Total Sugars', 'Protein', 'Vitamin D', 'Calcium',
#        'Iron', 'Potassium'],
#       dtype='object')

# %%
maxes = pd.read_csv('diet_maximums.csv')
mins = pd.read_csv('diet_minimums.csv')
mins
# Out:
#     Unnamed: 0                       Nutrition Source   C 1-3   F 4-8   M 4-8  \
# 0            0                          Energy    ---  1000.0  1200.0  1400.0
# 1            1                         Protein    RDA    13.0    19.0    19.0
# 2            2            Fiber, total dietary    ---    14.0    16.8    19.6
# 3            3                     Folate, DFE    RDA   150.0   200.0   200.0
# 4            4                     Calcium, Ca    RDA   700.0  1000.0  1000.0
# 5            5     Carbohydrate, by difference    RDA   130.0   130.0   130.0
# 6            6                        Iron, Fe    RDA     7.0    10.0    10.0
# 7            7                   Magnesium, Mg    RDA    80.0   130.0   130.0
# 8            8                          Niacin    RDA     6.0     8.0     8.0
# 9            9                   Phosphorus, P    RDA   460.0   500.0   500.0
# 10          10                    Potassium, K     AI  3000.0  3800.0  3800.0
# ...

# %%
mins['Nutrition'].tolist()
# Out:
# ['Energy',
#  'Protein',
#  'Fiber, total dietary',
#  'Folate, DFE',
#  'Calcium, Ca',
#  'Carbohydrate, by difference',
#  'Iron, Fe',
#  'Magnesium, Mg',
#  'Niacin',
#  'Phosphorus, P',
#  'Potassium, K',
#  'Riboflavin',
#  'Thiamin',
#  'Vitamin A, RAE',
#  'Vitamin B-12',
#  'Vitamin B-6',
#  'Vitamin C, total ascorbic acid',
#  'Vitamin E (alpha-tocopherol)',
#  'Vitamin K (phylloquinone)',
#  'Zinc, Zn']

# %%
keep = ['Energy', 'Protein', 'Fiber, total dietary','Calcium, Ca',
 'Carbohydrate, by difference', 'Iron, Fe', 'Potassium, K']
mins = mins[mins['Nutrition'].isin(keep)]
mins
# Out:
#     Unnamed: 0                    Nutrition Source   C 1-3   F 4-8   M 4-8  \
# 0            0                       Energy    ---  1000.0  1200.0  1400.0
# 1            1                      Protein    RDA    13.0    19.0    19.0
# 2            2         Fiber, total dietary    ---    14.0    16.8    19.6
# 4            4                  Calcium, Ca    RDA   700.0  1000.0  1000.0
# 5            5  Carbohydrate, by difference    RDA   130.0   130.0   130.0
# 6            6                     Iron, Fe    RDA     7.0    10.0    10.0
# 10          10                 Potassium, K     AI  3000.0  3800.0  3800.0
#
#     F 9-13  M 9-13  F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  M 31-50  \
# 0   1600.0  1800.0   1800.0   2200.0   2000.0   2400.0   1800.0   2200.0
# 1     34.0    34.0     46.0     52.0     46.0     56.0     46.0     56.0
# 2     22.4    25.2     25.2     30.8     28.0     33.6     25.2     30.8
# 4   1300.0  1300.0   1300.0   1300.0   1000.0   1000.0   1000.0   1000.0
# ...

# %%
mins.to_csv('cleanedmins.csv')
tjdata.to_csv('trader_joes_sub.csv')
